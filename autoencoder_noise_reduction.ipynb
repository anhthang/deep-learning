# %% [markdown]
# # Autoencoder for Noise Reduction
#
# The idea of encoding is to reduce the dimensions of input data so that the information is compressed.  The idea of decoding is to restore the original information from the compressed data.
#
# The autoencoder learns to encode and decode automatically (hence, the name).  As such, it is data specific and will not work on completely unseen data structure.  For example, an autoencoder trained on numbers does not work on alphabets.  Another limitation is that the compression is lossy.  It does not perfectly restore the original information.  It is, however, quite useful for noise reduction which we will see later in this notebook.
#
# The code in this notebook is based on **Building Autoencoders in Keras by Francois Chollet** [[1]](#ref1) and **Autoencoder Examples by Udacity** [[2]](#ref2).

# %% [markdown]
# ## MNIST
#
# MNIST is a well known database of handwritten digits [[3]](#ref3).

# %%
import numpy as np
import keras
from keras.layers import Input, Dense, Conv2D, MaxPooling2D, UpSampling2D
from keras.models import Model
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %% [markdown]
# The below will download MNIST dataset (if not already).  We ignore the labels.

# %%
(X_train, _), (X_test, _) = keras.datasets.mnist.load_data()
# Out:
# Downloading data from https://s3.amazonaws.com/img-datasets/mnist.npz
# 11493376/11490434 [==============================] - 1s 0us/step

# %% [markdown]
# The images in MNIST all have the same shape.  It has no color information.

# %%
X_train[0].shape
# Out:
# (28, 28)

# %% [markdown]
# Let's examine sample images.  We use 'gray' color map since it has no color information.

# %%
plt.figure(figsize=(10, 5))
for i in range(10):
    plt.subplot(1, 10, i+1)
    plt.imshow(X_train[i], cmap='gray')
    plt.xticks([])
    plt.yticks([])
plt.show()

# %% [markdown]
# ## Simple Autoencoder
#
# To introduce the idea of autoencoders, we start with a simple implementation based on a fully connected layers.  One hidden layer handles the encoding, and the output layer handles the decoding.
#
# Each of the input images is flatten to an array of 784 ($=28 \times 28$) data points.  This is then compressed into 32 data points by the fully connected layer.

# %%
inputs  = Input(shape=(784,))              # 28*28 flatten
enc_fc  = Dense( 32, activation='relu')    # compress using 32 neurons
encoded = enc_fc(inputs)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.

# %% [markdown]
# Then, we decode the encoded data to the original 784 data points.  The sigmoid will return values between 0 and 1.

# %%
dec_fc  = Dense(784, activation='sigmoid') # decompress to 784 pixels
decoded = dec_fc(encoded)

# %% [markdown]
# This whole processing becomes the trainable autoencoder model.  It is compressing and decompressing.  So, what's the point?  We talk about that later on.

# %%
# build the model to train
autoencoder = Model(inputs, decoded)
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3657: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %% [markdown]
# Let's preprocess the MNIST image data so that image data are normalized between 0 and 1.

# %%
def preprocess(x):
    x = x.astype('float32') / 255.
    return x.reshape(-1, np.prod(x.shape[1:])) # flatten

X_train = preprocess(X_train)
X_test  = preprocess(X_test)

# also create a validation set for training
X_train, X_valid = train_test_split(X_train, test_size=500)

# %% [markdown]
# Now, we train the autoencoder which compress the input image and then restore to the original size.  As such, our training data and label data are both the same image data.

# %%
autoencoder.fit(X_train, X_train, epochs=50, batch_size=128, validation_data=(X_valid, X_valid))
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# Train on 59500 samples, validate on 500 samples
# Epoch 1/50
# 59500/59500 [==============================] - 6s 103us/step - loss: 0.2284 - val_loss: 0.1600
# Epoch 2/50
# 59500/59500 [==============================] - 2s 35us/step - loss: 0.1423 - val_loss: 0.1274
# Epoch 3/50
# 59500/59500 [==============================] - 2s 36us/step - loss: 0.1195 - val_loss: 0.1123
# Epoch 4/50
# 59500/59500 [==============================] - 2s 36us/step - loss: 0.1079 - val_loss: 0.1042
# Epoch 5/50
# 59500/59500 [==============================] - 2s 36us/step - loss: 0.1013 - val_loss: 0.0992
# Epoch 6/50
# 59500/59500 [==============================] - 2s 36us/step - loss: 0.0976 - val_loss: 0.0966
# Epoch 7/50
# 59500/59500 [==============================] - 2s 36us/step - loss: 0.0958 - val_loss: 0.0951
# Epoch 8/50
# 59500/59500 [==============================] - 2s 36us/step - loss: 0.0949 - val_loss: 0.0944
# Epoch 9/50
# 59500/59500 [==============================] - 2s 37us/step - loss: 0.0944 - val_loss: 0.0940
# Epoch 10/50
# 59500/59500 [==============================] - 2s 36us/step - loss: 0.0941 - val_loss: 0.0936
# Epoch 11/50
# 59500/59500 [==============================] - 2s 36us/step - loss: 0.0939 - val_loss: 0.0935
# Epoch 12/50
# 59500/59500 [==============================] - 2s 36us/step - loss: 0.0937 - val_loss: 0.0935
# Epoch 13/50
# 59500/59500 [==============================] - 2s 36us/step - loss: 0.0936 - val_loss: 0.0933
# Epoch 14/50
# 59500/59500 [==============================] - 2s 37us/step - loss: 0.0935 - val_loss: 0.0931
# Epoch 15/50
# 59500/59500 [==============================] - 2s 36us/step - loss: 0.0934 - val_loss: 0.0930
# Epoch 16/50
# 59500/59500 [==============================] - 2s 36us/step - loss: 0.0934 - val_loss: 0.0931
# Epoch 17/50
# 59500/59500 [==============================] - 2s 36us/step - loss: 0.0933 - val_loss: 0.0930
# Epoch 18/50
# 59500/59500 [==============================] - 2s 37us/step - loss: 0.0933 - val_loss: 0.0930
# Epoch 19/50
# 59500/59500 [==============================] - 2s 36us/step - loss: 0.0932 - val_loss: 0.0931
# Epoch 20/50
# 59500/59500 [==============================] - 2s 35us/step - loss: 0.0932 - val_loss: 0.0929
# Epoch 21/50
# 59500/59500 [==============================] - 2s 36us/step - loss: 0.0931 - val_loss: 0.0928
# Epoch 22/50
# 59500/59500 [==============================] - 2s 36us/step - loss: 0.0931 - val_loss: 0.0929
# Epoch 23/50
# 59500/59500 [==============================] - 2s 37us/step - loss: 0.0931 - val_loss: 0.0928
# Epoch 24/50
# 59500/59500 [==============================] - 2s 35us/step - loss: 0.0931 - val_loss: 0.0927
# Epoch 25/50
# 59500/59500 [==============================] - 2s 35us/step - loss: 0.0930 - val_loss: 0.0930
# Epoch 26/50
# 59500/59500 [==============================] - 2s 36us/step - loss: 0.0930 - val_loss: 0.0930
# Epoch 27/50
# 59500/59500 [==============================] - 2s 37us/step - loss: 0.0930 - val_loss: 0.0928
# Epoch 28/50
# 59500/59500 [==============================] - 2s 36us/step - loss: 0.0930 - val_loss: 0.0927
# Epoch 29/50
# 59500/59500 [==============================] - 2s 36us/step - loss: 0.0929 - val_loss: 0.0927
# Epoch 30/50
# 59500/59500 [==============================] - 2s 35us/step - loss: 0.0929 - val_loss: 0.0930
# Epoch 31/50
# 59500/59500 [==============================] - 2s 35us/step - loss: 0.0929 - val_loss: 0.0928
# Epoch 32/50
# 59500/59500 [==============================] - 2s 35us/step - loss: 0.0929 - val_loss: 0.0928
# Epoch 33/50
# 59500/59500 [==============================] - 2s 36us/step - loss: 0.0929 - val_loss: 0.0927
# Epoch 34/50
# 59500/59500 [==============================] - 2s 37us/step - loss: 0.0929 - val_loss: 0.0927
# Epoch 35/50
# 59500/59500 [==============================] - 2s 36us/step - loss: 0.0928 - val_loss: 0.0928
# Epoch 36/50
# 59500/59500 [==============================] - 2s 35us/step - loss: 0.0928 - val_loss: 0.0927
# Epoch 37/50
# 59500/59500 [==============================] - 2s 35us/step - loss: 0.0928 - val_loss: 0.0929
# Epoch 38/50
# 59500/59500 [==============================] - 2s 36us/step - loss: 0.0928 - val_loss: 0.0927
# Epoch 39/50
# 59500/59500 [==============================] - 2s 35us/step - loss: 0.0928 - val_loss: 0.0927
# Epoch 40/50
# 59500/59500 [==============================] - 2s 35us/step - loss: 0.0928 - val_loss: 0.0929
# Epoch 41/50
# 59500/59500 [==============================] - 2s 35us/step - loss: 0.0928 - val_loss: 0.0929
# Epoch 42/50
# 59500/59500 [==============================] - 2s 36us/step - loss: 0.0927 - val_loss: 0.0927
# Epoch 43/50
# 59500/59500 [==============================] - 2s 36us/step - loss: 0.0927 - val_loss: 0.0926
# Epoch 44/50
# 59500/59500 [==============================] - 2s 36us/step - loss: 0.0927 - val_loss: 0.0927
# Epoch 45/50
# 59500/59500 [==============================] - 2s 36us/step - loss: 0.0927 - val_loss: 0.0926
# Epoch 46/50
# 59500/59500 [==============================] - 2s 36us/step - loss: 0.0927 - val_loss: 0.0926
# Epoch 47/50
# 59500/59500 [==============================] - 2s 35us/step - loss: 0.0927 - val_loss: 0.0925
# Epoch 48/50
# 59500/59500 [==============================] - 2s 36us/step - loss: 0.0927 - val_loss: 0.0925
# Epoch 49/50
# 59500/59500 [==============================] - 2s 35us/step - loss: 0.0927 - val_loss: 0.0925
# Epoch 50/50
# 59500/59500 [==============================] - 2s 36us/step - loss: 0.0927 - val_loss: 0.0926

# %% [markdown]
# Once the autoencoder is trained, we can use the encoding part to encode MNIST digit images.  By training an autoencoder, we are really training both the encoder and the decoder at the same time which is why the above training is done.

# %%
encoder = Model(inputs, encoded)

# %% [markdown]
# Now, we can compress MNIST images.

# %%
X_test_encoded = encoder.predict(X_test)

# %% [markdown]
# We can confirm the 784 pixels are now compressed into 32 data points.

# %%
X_test_encoded[0].shape
# Out:
# (32,)

# %% [markdown]
# Let's also build the decoder so that we can decode the encoded information into the original image size.  For the decoder, the input shape takes 32 data points as that is the size of encoded data.

# %%
decoder_inputs = Input(shape=(32,))
decoder = Model(decoder_inputs, dec_fc(decoder_inputs))

# %% [markdown]
# Let's decompress the compressed MNIST images.

# %%
X_test_decoded = decoder.predict(X_test_encoded)

# %% [markdown]
# The first row is the original image and the second row is the restored image.

# %%
def show_images(before_images, after_images):
    plt.figure(figsize=(10, 2))
    for i in range(10):
        # before
        plt.subplot(2, 10, i+1)
        plt.imshow(before_images[i].reshape(28, 28), cmap='gray')
        plt.xticks([])
        plt.yticks([])
        # after
        plt.subplot(2, 10, 10+i+1)
        plt.imshow(after_images[i].reshape(28, 28), cmap='gray')
        plt.xticks([])
        plt.yticks([])
    plt.show()
    
show_images(X_test, X_test_decoded)

# %% [markdown]
# As can be seen, the decoded images do not completely restore the original image.

# %% [markdown]
# ## Convolutional Autoencoder
#
# We could add more layers to make the network deeper to improve the performance.  But since we are working on images, we could make use of convolutional neural network to improve the quality of compression and decompression.

# %%
def make_convolutional_autoencoder():
    # encoding
    inputs = Input(shape=(28, 28, 1))
    x = Conv2D(16, 3, activation='relu', padding='same')(inputs)
    x = MaxPooling2D(padding='same')(x)
    x = Conv2D( 8, 3, activation='relu', padding='same')(x)
    x = MaxPooling2D(padding='same')(x)
    x = Conv2D( 8, 3, activation='relu', padding='same')(x)
    encoded = MaxPooling2D(padding='same')(x)    
    
    # decoding
    x = Conv2D( 8, 3, activation='relu', padding='same')(encoded)
    x = UpSampling2D()(x)
    x = Conv2D( 8, 3, activation='relu', padding='same')(x)
    x = UpSampling2D()(x)
    x = Conv2D(16, 3, activation='relu')(x) # <= padding='valid'!
    x = UpSampling2D()(x)
    decoded = Conv2D(1, 3, activation='sigmoid', padding='same')(x)    
    
    # autoencoder
    autoencoder = Model(inputs, decoded)
    autoencoder.compile(optimizer='adam', loss='binary_crossentropy')
    return autoencoder

# %% [markdown]
# Let's make a convolutional autoencoder and examine the layers.

# %%
autoencoder = make_convolutional_autoencoder()

autoencoder.summary()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:2239: The name tf.image.resize_nearest_neighbor is deprecated. Please use tf.compat.v1.image.resize_nearest_neighbor instead.
#
# Model: "model_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         (None, 28, 28, 1)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 28, 28, 16)        160
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 14, 14, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 14, 14, 8)         1160
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 7, 7, 8)           0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 7, 7, 8)           584
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 4, 4, 8)           0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 4, 4, 8)           584
# _________________________________________________________________
# up_sampling2d_1 (UpSampling2 (None, 8, 8, 8)           0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 8, 8, 8)           584
# _________________________________________________________________
# up_sampling2d_2 (UpSampling2 (None, 16, 16, 8)         0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 14, 14, 16)        1168
# _________________________________________________________________
# up_sampling2d_3 (UpSampling2 (None, 28, 28, 16)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 28, 28, 1)         145
# =================================================================
# Total params: 4,385
# Trainable params: 4,385
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# The `UpSampling2D` will repeats the rows and columns twice.  Effectively reversing the effect of the `MaxPooling2D`.
#
# If you look closely, the `UpSampling2D` is doubling the height and width: (4,4) => (8,8) => (16,16).  But the `conv2d_13 (Conv2D)` uses the `padding='valid'` which is the default and reduces the height and width = (14,14) so that we can up sample again to (28,28).  This is a minor details but important in practice.

# %% [markdown]
# Let's reshape the image data to the format the convolutional autoencoder expects for training.

# %%
X_train = X_train.reshape(-1, 28, 28, 1)
X_valid = X_valid.reshape(-1, 28, 28, 1)
X_test  = X_test.reshape(-1, 28, 28, 1)

autoencoder.fit(X_train, X_train, epochs=50, batch_size=128, validation_data=(X_valid, X_valid))
# Out:
# Train on 59500 samples, validate on 500 samples
# Epoch 1/50
# 59500/59500 [==============================] - 9s 151us/step - loss: 0.2179 - val_loss: 0.1457
# Epoch 2/50
# 59500/59500 [==============================] - 6s 106us/step - loss: 0.1366 - val_loss: 0.1278
# Epoch 3/50
# 59500/59500 [==============================] - 6s 106us/step - loss: 0.1243 - val_loss: 0.1192
# Epoch 4/50
# 59500/59500 [==============================] - 6s 104us/step - loss: 0.1177 - val_loss: 0.1138
# Epoch 5/50
# 59500/59500 [==============================] - 6s 104us/step - loss: 0.1137 - val_loss: 0.1107
# Epoch 6/50
# 59500/59500 [==============================] - 6s 105us/step - loss: 0.1108 - val_loss: 0.1080
# Epoch 7/50
# 59500/59500 [==============================] - 6s 104us/step - loss: 0.1086 - val_loss: 0.1060
# Epoch 8/50
# 59500/59500 [==============================] - 6s 105us/step - loss: 0.1067 - val_loss: 0.1053
# Epoch 9/50
# 59500/59500 [==============================] - 6s 104us/step - loss: 0.1053 - val_loss: 0.1032
# Epoch 10/50
# 59500/59500 [==============================] - 6s 104us/step - loss: 0.1041 - val_loss: 0.1022
# Epoch 11/50
# 59500/59500 [==============================] - 6s 104us/step - loss: 0.1030 - val_loss: 0.1011
# Epoch 12/50
# 59500/59500 [==============================] - 6s 104us/step - loss: 0.1022 - val_loss: 0.1003
# Epoch 13/50
# 59500/59500 [==============================] - 6s 104us/step - loss: 0.1014 - val_loss: 0.0997
# Epoch 14/50
# 59500/59500 [==============================] - 6s 104us/step - loss: 0.1008 - val_loss: 0.0995
# Epoch 15/50
# 59500/59500 [==============================] - 6s 104us/step - loss: 0.1001 - val_loss: 0.0983
# Epoch 16/50
# 59500/59500 [==============================] - 6s 105us/step - loss: 0.0996 - val_loss: 0.0978
# Epoch 17/50
# 59500/59500 [==============================] - 6s 104us/step - loss: 0.0991 - val_loss: 0.0975
# Epoch 18/50
# 59500/59500 [==============================] - 6s 104us/step - loss: 0.0986 - val_loss: 0.0977
# Epoch 19/50
# 59500/59500 [==============================] - 6s 104us/step - loss: 0.0982 - val_loss: 0.0974
# Epoch 20/50
# 59500/59500 [==============================] - 6s 103us/step - loss: 0.0978 - val_loss: 0.0967
# Epoch 21/50
# 59500/59500 [==============================] - 6s 103us/step - loss: 0.0974 - val_loss: 0.0959
# Epoch 22/50
# 59500/59500 [==============================] - 6s 104us/step - loss: 0.0970 - val_loss: 0.0959
# Epoch 23/50
# 59500/59500 [==============================] - 6s 105us/step - loss: 0.0967 - val_loss: 0.0952
# Epoch 24/50
# 59500/59500 [==============================] - 6s 103us/step - loss: 0.0964 - val_loss: 0.0950
# Epoch 25/50
# 59500/59500 [==============================] - 6s 103us/step - loss: 0.0961 - val_loss: 0.0947
# Epoch 26/50
# 59500/59500 [==============================] - 6s 103us/step - loss: 0.0958 - val_loss: 0.0946
# Epoch 27/50
# 59500/59500 [==============================] - 6s 103us/step - loss: 0.0955 - val_loss: 0.0941
# Epoch 28/50
# 59500/59500 [==============================] - 6s 102us/step - loss: 0.0952 - val_loss: 0.0943
# Epoch 29/50
# 59500/59500 [==============================] - 6s 103us/step - loss: 0.0949 - val_loss: 0.0939
# Epoch 30/50
# 59500/59500 [==============================] - 6s 102us/step - loss: 0.0946 - val_loss: 0.0938
# Epoch 31/50
# 59500/59500 [==============================] - 6s 102us/step - loss: 0.0945 - val_loss: 0.0935
# Epoch 32/50
# 59500/59500 [==============================] - 6s 103us/step - loss: 0.0941 - val_loss: 0.0932
# Epoch 33/50
# 59500/59500 [==============================] - 6s 103us/step - loss: 0.0940 - val_loss: 0.0927
# Epoch 34/50
# 59500/59500 [==============================] - 6s 103us/step - loss: 0.0938 - val_loss: 0.0926
# Epoch 35/50
# 59500/59500 [==============================] - 6s 102us/step - loss: 0.0936 - val_loss: 0.0924
# Epoch 36/50
# 59500/59500 [==============================] - 6s 101us/step - loss: 0.0933 - val_loss: 0.0926
# Epoch 37/50
# 59500/59500 [==============================] - 6s 101us/step - loss: 0.0931 - val_loss: 0.0920
# Epoch 38/50
# 59500/59500 [==============================] - 6s 101us/step - loss: 0.0930 - val_loss: 0.0920
# Epoch 39/50
# 59500/59500 [==============================] - 6s 101us/step - loss: 0.0928 - val_loss: 0.0919
# Epoch 40/50
# 59500/59500 [==============================] - 6s 100us/step - loss: 0.0927 - val_loss: 0.0918
# Epoch 41/50
# 59500/59500 [==============================] - 6s 101us/step - loss: 0.0925 - val_loss: 0.0914
# Epoch 42/50
# 59500/59500 [==============================] - 6s 102us/step - loss: 0.0923 - val_loss: 0.0914
# Epoch 43/50
# 59500/59500 [==============================] - 6s 101us/step - loss: 0.0922 - val_loss: 0.0910
# Epoch 44/50
# 59500/59500 [==============================] - 6s 100us/step - loss: 0.0920 - val_loss: 0.0910
# Epoch 45/50
# 59500/59500 [==============================] - 6s 101us/step - loss: 0.0919 - val_loss: 0.0907
# Epoch 46/50
# 59500/59500 [==============================] - 6s 100us/step - loss: 0.0917 - val_loss: 0.0908
# Epoch 47/50
# 59500/59500 [==============================] - 6s 101us/step - loss: 0.0916 - val_loss: 0.0906
# Epoch 48/50
# 59500/59500 [==============================] - 6s 100us/step - loss: 0.0915 - val_loss: 0.0904
# Epoch 49/50
# 59500/59500 [==============================] - 6s 101us/step - loss: 0.0913 - val_loss: 0.0903
# Epoch 50/50
# 59500/59500 [==============================] - 6s 101us/step - loss: 0.0912 - val_loss: 0.0901

# %% [markdown]
# We just want to see the quality of compression/decompression.  So, let's just feed forward test images to see how the restored digits look like.

# %%
X_test_decoded = autoencoder.predict(X_test)

show_images(X_test, X_test_decoded)

# %% [markdown]
# Although not perfect, the restored digits look better than the ones restored by the simple autoencoder.

# %% [markdown]
# ## Noise Reduction by Autoencoder
#
# Let's try noise reduction effect using the convolutional autoencoder.  We add random noises to the MINST image data and use them as input for training.

# %%
def add_noise(x, noise_factor=0.2):
    x = x + np.random.randn(*x.shape) * noise_factor
    x = x.clip(0., 1.)
    return x
    
X_train_noisy = add_noise(X_train)
X_valid_noisy = add_noise(X_valid)
X_test_noisy  = add_noise(X_test)

# %% [markdown]
# We train a new autoencoder with the noisy data as input and the original data as expected output.

# %%
autoencoder = make_convolutional_autoencoder()
autoencoder.fit(X_train_noisy, X_train, epochs=50, batch_size=128, validation_data=(X_valid_noisy, X_valid))
# Out:
# Train on 59500 samples, validate on 500 samples
# Epoch 1/50
# 59500/59500 [==============================] - 8s 126us/step - loss: 0.2164 - val_loss: 0.1584
# Epoch 2/50
# 59500/59500 [==============================] - 7s 115us/step - loss: 0.1471 - val_loss: 0.1368
# Epoch 3/50
# 59500/59500 [==============================] - 7s 113us/step - loss: 0.1318 - val_loss: 0.1263
# Epoch 4/50
# 59500/59500 [==============================] - 7s 115us/step - loss: 0.1245 - val_loss: 0.1207
# Epoch 5/50
# 59500/59500 [==============================] - 7s 115us/step - loss: 0.1202 - val_loss: 0.1169
# Epoch 6/50
# 59500/59500 [==============================] - 7s 113us/step - loss: 0.1171 - val_loss: 0.1142
# Epoch 7/50
# 59500/59500 [==============================] - 7s 114us/step - loss: 0.1147 - val_loss: 0.1128
# Epoch 8/50
# 59500/59500 [==============================] - 7s 114us/step - loss: 0.1128 - val_loss: 0.1107
# Epoch 9/50
# 59500/59500 [==============================] - 7s 114us/step - loss: 0.1111 - val_loss: 0.1091
# Epoch 10/50
# 59500/59500 [==============================] - 7s 113us/step - loss: 0.1098 - val_loss: 0.1079
# Epoch 11/50
# 59500/59500 [==============================] - 7s 113us/step - loss: 0.1087 - val_loss: 0.1069
# Epoch 12/50
# 59500/59500 [==============================] - 7s 113us/step - loss: 0.1077 - val_loss: 0.1059
# Epoch 13/50
# 59500/59500 [==============================] - 7s 113us/step - loss: 0.1070 - val_loss: 0.1058
# Epoch 14/50
# 59500/59500 [==============================] - 7s 112us/step - loss: 0.1063 - val_loss: 0.1048
# Epoch 15/50
# 59500/59500 [==============================] - 7s 113us/step - loss: 0.1057 - val_loss: 0.1039
# Epoch 16/50
# 59500/59500 [==============================] - 7s 113us/step - loss: 0.1052 - val_loss: 0.1038
# Epoch 17/50
# 59500/59500 [==============================] - 7s 113us/step - loss: 0.1047 - val_loss: 0.1034
# Epoch 18/50
# 59500/59500 [==============================] - 7s 113us/step - loss: 0.1043 - val_loss: 0.1031
# Epoch 19/50
# 59500/59500 [==============================] - 7s 112us/step - loss: 0.1039 - val_loss: 0.1024
# Epoch 20/50
# 59500/59500 [==============================] - 7s 114us/step - loss: 0.1035 - val_loss: 0.1024
# Epoch 21/50
# 59500/59500 [==============================] - 7s 115us/step - loss: 0.1032 - val_loss: 0.1018
# Epoch 22/50
# 59500/59500 [==============================] - 7s 113us/step - loss: 0.1029 - val_loss: 0.1016
# Epoch 23/50
# 59500/59500 [==============================] - 7s 112us/step - loss: 0.1026 - val_loss: 0.1012
# Epoch 24/50
# 59500/59500 [==============================] - 7s 112us/step - loss: 0.1023 - val_loss: 0.1009
# Epoch 25/50
# 59500/59500 [==============================] - 7s 113us/step - loss: 0.1020 - val_loss: 0.1010
# Epoch 26/50
# 59500/59500 [==============================] - 7s 113us/step - loss: 0.1018 - val_loss: 0.1006
# Epoch 27/50
# 59500/59500 [==============================] - 7s 113us/step - loss: 0.1014 - val_loss: 0.1002
# Epoch 28/50
# 59500/59500 [==============================] - 7s 111us/step - loss: 0.1012 - val_loss: 0.0998
# Epoch 29/50
# 59500/59500 [==============================] - 7s 111us/step - loss: 0.1009 - val_loss: 0.1000
# Epoch 30/50
# 59500/59500 [==============================] - 7s 110us/step - loss: 0.1007 - val_loss: 0.0996
# Epoch 31/50
# 59500/59500 [==============================] - 7s 112us/step - loss: 0.1005 - val_loss: 0.0992
# Epoch 32/50
# 59500/59500 [==============================] - 7s 110us/step - loss: 0.1002 - val_loss: 0.0990
# Epoch 33/50
# 59500/59500 [==============================] - 7s 111us/step - loss: 0.1000 - val_loss: 0.0988
# Epoch 34/50
# 59500/59500 [==============================] - 7s 111us/step - loss: 0.0999 - val_loss: 0.0986
# Epoch 35/50
# 59500/59500 [==============================] - 7s 111us/step - loss: 0.0997 - val_loss: 0.0983
# Epoch 36/50
# 59500/59500 [==============================] - 7s 111us/step - loss: 0.0995 - val_loss: 0.0981
# Epoch 37/50
# 59500/59500 [==============================] - 7s 110us/step - loss: 0.0993 - val_loss: 0.0984
# Epoch 38/50
# 59500/59500 [==============================] - 7s 111us/step - loss: 0.0992 - val_loss: 0.0978
# Epoch 39/50
# 59500/59500 [==============================] - 7s 111us/step - loss: 0.0989 - val_loss: 0.0976
# Epoch 40/50
# 59500/59500 [==============================] - 7s 112us/step - loss: 0.0989 - val_loss: 0.0984
# Epoch 41/50
# 59500/59500 [==============================] - 7s 111us/step - loss: 0.0987 - val_loss: 0.0976
# Epoch 42/50
# 59500/59500 [==============================] - 7s 110us/step - loss: 0.0985 - val_loss: 0.0975
# Epoch 43/50
# 59500/59500 [==============================] - 7s 112us/step - loss: 0.0985 - val_loss: 0.0973
# Epoch 44/50
# 59500/59500 [==============================] - 7s 111us/step - loss: 0.0983 - val_loss: 0.0971
# Epoch 45/50
# 59500/59500 [==============================] - 7s 111us/step - loss: 0.0982 - val_loss: 0.0970
# Epoch 46/50
# 59500/59500 [==============================] - 7s 111us/step - loss: 0.0981 - val_loss: 0.0968
# Epoch 47/50
# 59500/59500 [==============================] - 7s 111us/step - loss: 0.0980 - val_loss: 0.0971
# Epoch 48/50
# 59500/59500 [==============================] - 7s 111us/step - loss: 0.0979 - val_loss: 0.0968
# Epoch 49/50
# 59500/59500 [==============================] - 7s 111us/step - loss: 0.0978 - val_loss: 0.0967
# Epoch 50/50
# 59500/59500 [==============================] - 7s 112us/step - loss: 0.0976 - val_loss: 0.0967

# %% [markdown]
# We pass the noisy images to the autoencoder to see the restored images.

# %%
X_test_decoded = autoencoder.predict(X_test_noisy)

show_images(X_test_noisy, X_test_decoded)

# %% [markdown]
# Not bad, right?

# %% [markdown]
# ## References
#
# <a id="ref1"></a>
# ### [1] Building Autoencoders in Keras
#
# Francois Chollet
#
# https://blog.keras.io/building-autoencoders-in-keras.html
#
# <a id="ref2"></a>
# ### [2] Autoencoder Example in Tensorflow
#
# Udacity
#
# https://github.com/udacity/deep-learning/tree/master/autoencoder
#
# <a id="ref3"></a>
# ### [3] MNIST dataset
#
# Yann LeCun
#
# http://yann.lecun.com/exdb/mnist/
